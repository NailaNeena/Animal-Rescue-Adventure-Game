# %% [markdown]
# # Animal Rescue Adventure Game
#
# We have made some changes in the script of this book, just to make it a bit challenging for users to play the game. Here is the map of the game and its rules.
# Rule is the predator and the pray should not be on the same side with the farmer.
#
#
# 1) Farmer Home
#
# 2) River
#
# 3) Zoo
#
# Our map can be visualized as follows:
#
#
#     Home --> River (Challenge) --> Zoo(win)
#             |                |
#              `----------------`------> Fail

# %%
import colorama
from colorama import Fore, Style



#start of the scene one
def start():
    
    """
    DocString:
    
    Reference: Book - Animal Rescue Friends
    Name: Naila Jan
    Updated Date: 01.27.2022

    Introduction:
    A farmer have a lion that he wants to donate to the zoo. While going to zoo he faced a challnage to cross the river with both animals and grass, because boat can carry only one thing at a time. 
    
    Purpose: 
    Take the Lion to Zoo by crossing the river safily. 
    
    Game Instructions:
    while crosing the river, make sure you have to carry right thing at a time. Goat and Grass or Goat and Lion can not be on the same side when farmer on the other side. 
    Known Bugs and/or Errors:
    None.    

        
    """
    
    #added the header of the game
    print("""
        ✨✨✨✨✨✨✨✨✨
         River Crossing Challenge.
        ✨✨✨✨✨✨✨✨✨\n""")
    
    
    print(Fore.BLUE+"""
A farmer have a lion that he wants to donate to the zoo. Unfortunately, the zoo is almost two days away from the farmer's home.
He wants to drop the health lion safely in the zoo. He wants to carry some fresh food as well to feed the lion. 
Help the farmer to decide the right pray for the lion """)
    global right_side
    global left_side
    
    right_side = ["Lion", "Goat", "Grass"]
    left_side =[]
    
    Question1 = input(prompt= """Which of the following food should the farmer carry for lion?\n
    
    * Grass
    * Vegetables
    * Meat
    """).capitalize()
    if "Grass" in Question1 or "Vegetables" in Question1:
        print("Sorry, Lion only eat meat.")
    elif "Meat" in Question1:
        print("Yes that's the right option. For meat the farmer will carry goat.\n")
    else:
        print(Fore.RED+ "Invalid Entry")
    print("For feeding the lion, the farmer will carry the goat alive.\n\n ")
    Question2 = input(prompt= """Which of the following food should the farmer carry to feed the goat?\n
    
    * Grass
    * Milk
    * Meat
    
    \n""").capitalize()
    
    if "Meat" in Question2 or "Milk" in Question2:
        print("Sorry, Goat only eat grass.")
    elif "Grass" in Question2:
        print("Yes that's the right option. For goat the farmer will carry grass.\n")
    else:
        print(Fore.RED+ "Invalid Entry")
    
    print("""So the farmer decided to carry the Lion , Goat and grass but there is a river on his way to the Zoo. 
The farmer wants to cross the river with Lion, Goat and grass safely. """)
    scene_01()

    
def scene_01():

    print("""Now farmer reached to the right side of the river and wants to bring the Lion,  goat, and Grass across the river. 
The boat is tiny and can only carry one passenger at a time. If he leaves the Lion and the goat alone together, the Lion will eat the goat. 
If he leaves the goat and the Grass alone together, the goat will eat the Grass. The challenge is how can he bring all three safely across the river?\n """)
    #list the things that need to move from one side to other
    

    print("You are on the right side of river with your stuff and a boat. \n")
    
    ## scene1  R.S--> Lion, Goat, Grass & L.S --> []
    #print the list of things
    for element in right_side:
        print(element) 
    try: 
        #get user input and print
        scene_1= input(prompt="Select one of the following option:").capitalize()
        if "Lion"in scene_1: #set the condition for option Lion
                print(Fore.RED+ " Sorry, try again because Goat ate the Grass on the Right side.\n")
                fail() #that's a fail condition
        elif "Grass"in scene_1: #set the condition for option Grass
                print( Fore.RED+ "Sorry, try again because Lion ate the Goat on the Right side.\n")
                fail() ##that's a fail condition
        elif "Goat"in scene_1: #set the condition for option Goat
                left_side.append("Goat")
                right_side.remove("Goat")
                print(Fore.BLUE+"Now you have Goat on Left side of the river with boat\n")

                scene_02() # move to scene two if user select Goat
        else: 
            print("Invalid entry, Please try again" )
            fail()
    except:
        print("Kindly enter one word answer in the given options")
        print("Invalid entry")

#end of scene01

print("**"*40)

#### Start of scene 2
def scene_02():
     
        ## scene2  R.S--> Lion, Grass & L.S --> Goat
    print( "🐐","🌳","~~","🛶", "~`~~`~~~`~-~`~~-`~~ ","~","🐅", "🌾\n")
    scene_2= input(prompt="While going back to right side, do you want to carry any thing in the boat. Press Yes/No").capitalize()

    #display the options
    if "Yes"in scene_2 or "Y"in scene_2  :
        left_side.remove("Goat")   
        right_side.append("Goat")
        scene_01() 
    elif "No"in scene_2 or "N"in scene_2 : 
        print("Now you are on the Right side with boat.\n")
        scene_03() #move to scene 3 in case user choose not to move anything 
    else:
        print("Invalid Entry, Please Try again") #any other input, display the error message and back to scene two
        scene_02() # move to scene 2
            
#scene_02()
## End of scene 2 
def scene_03():
     ## scene3  R.S--> Lion, Grass & L.S --> Goat
    print( "🐐","🌳","~~", "~`~~`~~~`~-~`~~-`~~ ""🛶","~","🐅", "🌾\n")
    for element in right_side:
        print(element) 
        #display the updated list of things on both sides
    scene_3= input(prompt= "You are on the right side select any of the following options:").capitalize()
       #set the conditions for each user input
    
    if "Lion" in scene_3:
        left_side.append("Lion")
        right_side.remove("Lion")
        print(Fore.GREEN + "Congratulation !, You safely crossed the river for Goat and Lion \n")

        scene_04() # move to scene 5
    elif "Grass" in scene_3:   #scene3b  R.S --> Lion & L.S --> Goat, Grass
        left_side.append("Grass")
        right_side.remove("Grass")
        print(Fore.GREEN + "Congratulation !, You safely crossed the river for Goat and Lion \n")

        scene_05() # move to scene 5
    else:
        print("Invalid Entry") #in case user insert any other value 
        scene_03() # move to scene 3
    
            

## End of scene_03()

#Start of scene four 
def scene_04():  #scene4  R.S --> Grass & L.S --> Goat, Lion
    print( "🐅","🐐","🌳","~~","🛶", "~`~~`~~~`~-~`~~-`~~ ","~","🌾\n")
    scene_4=input(prompt="While going back to the right side do you want to carry anything? Hint enter Yes/No ").capitalize()
    
    if "Yes"in scene_4 or "Y"in scene_4: #scene3a  R.S --> Grass & L.S --> Goat, Lion
        for element in left_side: #list the elements on both sides 
            print(element) 
        #get the user input and apply conditions for each input    
        scene_4a= input("select one of the above option: ").capitalize()
        if "Lion"in scene_4a:
            left_side.remove("Lion")
            right_side.append("Lion")
            
            scene_03() #move to scene 3
        elif "Goat"in scene_4a: #R.S 4--> Goat, Grass & L.S -->  Lion
            left_side.remove("Goat")
            right_side.append("Goat")
            
            scene_06() #move to scene 6
        else:
            print("Invalid Entry, Try again")
            scene_04() #move to scene 4
                    
    elif "No"in scene_4 or "N"in scene_4:  #scene3  R.S --> Grass & L.S --> Goat, Lion --> Fail
            print(Fore.RED+ "Sorry try again, predator attacked on its pray on the other side")
            fail()   # move to scene 4       
                
    else:
        print("Invalid Enter, Please enter a Yes/No")
        scene_04() 
            #moving back to scene 4

            

#start of scene5
def scene_05():  #scene5  R.S --> Lion & L.S --> Goat, Grass
    
    # input from the user if they want to carry anything in the boat
    scene_5=input(prompt="While going back to the right side do yo want to carry anything? Hint enter Yes/No ").capitalize()
    print( "🐐","🌾","🌳","~~","🛶", "~`~~`~~~`~-~`~~-`~~ ","~","🐅\n")
    # if conditions to handel the inputs of the user
    if "Yes"in scene_5 or "Y"in scene_5: #scene3a  R.S --> lion & L.S --> Goat, Grass
        for element in left_side:
            print(element) #print the list of options 
        scene_5a= input("Select one of the above option: ").capitalize()
        if "Grass"in scene_5a:
            left_side.remove("Grass")
            right_side.append("Grass")
            
            scene_03() #move to scene 3
        elif "Goat"in scene_5a:  #R.S 4--> Goat,lion & L.S -->  Grass
            left_side.remove("Goat")
            right_side.append("Goat")
            
            scene_07() #move to scene 7
        else:
            print("Invalid Entry, Try again")
            scene_05() #move to scene 5
                    
    elif "No"in scene_5 or "N"in scene_5:  #scene3  R.S --> lion & L.S --> Goat, Grass --> Fail
            print(Fore.RED+ "Sorry try again, predator attacked on its pray on the other side")
            fail()   #move to scene 5    
                
    else:
        print("Invalid Enter")
        scene_05()  #move to scene 5
            

## End of scene_05()

#start if scene 6
def scene_06():  #scene6  R.S --> Goat, Grass & L.S --> Lion
    print( "🐅","🌳","~~", "~`~~`~~~`~-~`~~-`~~ ","🛶","~","🐐","🌾\n")
    for element in right_side: #print the list of elements from updated list
        print(element) 
    scene_6= input(prompt="Select one of the following option: ").capitalize()
    if "Grass"in scene_6:
        right_side.remove("Grass")
        left_side.append("Grass")
        #move to scene 8
        scene_08() 
    elif "Goat"in scene_6:  #R.S 4-->  Grass & L.S -->  Lion,Goat
        right_side.remove("Goat")
        left_side.append("Goat")
        
        scene_04() #move to scene 4
    else:
        print("Invalid Entry, Try again")
        scene_06() #move to scene 6
                      
            

## End of scene_06()


#start of scene 7
def scene_07():  #R.S 7--> Lion,Goat  & L.S -->  Grass, Action on right side
    print( "🌾","🌳","~~", "~`~~`~~~`~-~`~~-`~~ ","🛶","~","🐅","🐐\n")
    for element in right_side:
            print(element) 
    scene_7= input(prompt="Select one of the following option: ").capitalize()
    #handeling user inputs using if conditions
    if "Lion"in scene_7:
        right_side.remove("Lion")
        left_side.append("Lion")
        # move to scene 8
        scene_08()
        
    elif "Goat"in scene_7:  #R.S 4-->  Grass & L.S -->  Lion,Goat
        right_side.remove("Goat")
        left_side.append("Goat")
        # move to scene 5
        scene_05()
    else:
        print("Invalid Entry, Try again")
        scene_07() # move to scene 7
    

#end of scene_07()


# start of scene 8 
def scene_08(): #R.S 8--> Goat,  & L.S -->  Grass, lion, Action on left side
    print( "🐅","🌾","🌳","~~","🛶", "~`~~`~~~`~-~`~~-`~~ ","~","🐐\n")
    scene_8=input(prompt="While going back to the right side do yo want to carry anything? Hint enter Yes/No ").capitalize()      
    if "Yes"in scene_8 or "Y" in scene_8: 
        for element in left_side:
                print(element)  #print list of elements
        scene_8a= input(prompt= "Select one of the following option: ").capitalize()
        if "Lion"in scene_8a:
            left_side.remove("Lion")
            right_side.append("Lion")
            
            scene_07() # move to scene 7
        elif "Grass"in scene_8a:  #R.S 4-->  Grass & L.S -->  Lion,Goat
            left_side.remove("Grass")
            right_side.append("Grass")
            
            scene_06() # move to scene 6 
        else:
            print("Invalid Entry, Try again")
            scene_08() # move to scene 8
            
    elif "No"in scene_8 or "N" in scene_8: #scene3  R.S --> lion & L.S --> Goat, Grass --> Fail
              scene_09()  # move to scene 9       
                
    else:
        print("Invalid Enter, Please enter a Yes/No")
        scene_08() # move to scene 8
    
    



#start of scene 9
def scene_09(): #R.S 9--> [],  & L.S -->  Grass, lion, Goat
    print( "🐅","🌾","🌳","~~", "~`~~`~~~`~-~`~~-`~~ ","🛶","~","🐐\n")
    
    for element in right_side: # print all the elements 
            print(element) 
    #user input for selecting one of the option available
    scene_9= input(prompt="Please select the only item lift: ").capitalize()
    #if condition to handel user input
    if "Goat"in scene_9: 
        right_side.remove("Goat")
        left_side.append("Goat")
        print("Congratulations !, You have successfully crossed all the items to the left side.")
        print("🐐","🐅","🌾","🌳","~~","🛶", "~`~~`~~~`~-~`~~-`~~ ")
        zoo()
    else:
        print("Invalid Entry, Try again")
        scene_09() # move to scene 9
        
#start of the zoo function
def zoo():
    print("""After two days of hective long journey, you have successfully reached to the zoo with healthy Lion.
Now he wants to put him in the right cage. \n""")
    Question1= input(prompt= """Where do you want to put the Lion.
    
    * With Zebra
    * With Elephant
    * In alone Cage
     
     """).casefold()
    if "zebra" in Question1 or "elephant" in Question1:
        print("Lion could hurt the other animals, So we should put him in a separate cage.")
    elif "alone" in Question1 or "cage" in Question1:
        print("Congratulations !!!, You have successfully reached to the right cage with healthy Lion")
        win()

    
    
        
#start of the win function        
def win():
    print("""
🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆
🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆
🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆🎆

Congratulations! 

You Won!!

""")


 #start of the fail function   
def fail():
    print("""Predator attacked on its pray.
    
    😥😥😥😥😥😥😥😥😥😥😥😥😥😥😥😥
    
    You Loss!
    
    Thanks for playing the game.
    """)
start()
#end of the game
# Out:
# ********************************************************************************
#
#         ✨✨✨✨✨✨✨✨✨
#          River Crossing Challenge.
#         ✨✨✨✨✨✨✨✨✨
#
#
# A former have a lion that he wants to donate to the zoo. Unfortunately, the zoo is almost two days away from the farmer's home.
# He wants to drop the health lion safely in the zoo. He wants to carry some fresh food as well to feed the lion.
# Help the former to decide the right pray for the lion
# Which of the following food should the former carry for lion?
#
#
#     * Grass
#     * Vegetables
#     * Meat
#     grass
# Sorry, Lion only eat meat.
# For feeding the lion, the former will carry the goat alive.
#
#
# Which of the following food should the former carry to feed the goat?
#
#
#     * Grass
#     * Milk
#     * Meat
#
#
# grass
# Yes that's the right option. For goat the former will carry grass.
#
# So the farmer decided to carry the Lion , Goat and grass but there is a river on his way to the Zoo.
# ...

# %%
()
# Out:
# ()
